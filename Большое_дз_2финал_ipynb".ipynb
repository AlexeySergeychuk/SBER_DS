# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexeySergeychuk/SBER_DS/blob/main/%D0%91%D0%BE%D0%BB%D1%8C%D1%88%D0%BE%D0%B5_%D0%B4%D0%B7_2%D1%84%D0%B8%D0%BD%D0%B0%D0%BB_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.feature_selection import VarianceThreshold
from sklearn import metrics
from sklearn.metrics import r2_score
from sklearn.model_selection import learning_curve, GridSearchCV, train_test_split
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import Ridge, LinearRegression, LogisticRegression
from sklearn.svm import SVC
from sklearn import tree

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-32bbf53a-0cc6-4f1e-af12-d937915bda32" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-32bbf53a-0cc6-4f1e-af12-d937915bda32">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ThoraricSurgery.csv to ThoraricSurgery (1).csv
# {'ThoraricSurgery.csv': b'id,DGN,PRE4,PRE5,PRE6,PRE7,PRE8,PRE9,PRE10,PRE11,PRE14,PRE17,PRE19,PRE25,PRE30,PRE32,AGE,Risk1Yr\r\n1,DGN2,2.88,2.16,PRZ1,F,F,F,T,T,OC14,F,F,F,T,F,60,F\r\n2,DGN3,3.4,1.88,PRZ0,F,F,F,F,F,OC12,F,F,F,T,F,51,F\r\n3,DGN3,2.76,2.08,PRZ1,F,F,F,T,F,OC11,F,F,F,T,F,59,F\r\n4,DGN3,3.68,3.04,PRZ0,F,F,F,F,F,OC11,F,F,F,F,F,54,F\r\n5,DGN3,2.44,0.96,PRZ2,F,T,F,T,T,OC11,F,F,F,T,F,73,T\r\n6,DGN3,2.48,1.88,PRZ1,F,F,F,T,F,OC11,F,F,F,F,F,51,F\r\n7,DGN3,4.36,3.28,PRZ1,F,F,F,T,F,OC12,T,F,F,T,F,59,T\r\n8,DGN2,3.19,2.5,PRZ1,F,F,F,T,F,OC11,F,F,T,T,F,66,T\r\n9,DGN3,3.16,2.64,PRZ2,F,F,F,T,T,OC11,F,F,F,T,F,68,F\r\n10,DGN3,2.32,2.16,PRZ1,F,F,F,T,F,OC11,F,F,F,T,F,54,F\r\n11,DGN3,2.56,2.32,PRZ0,F,T,F,T,F,OC12,F,F,F,F,F,60,F\r\n12,DGN3,4.28,4.44,PRZ1,F,F,F,F,F,OC12,F,F,F,T,F,58,F\r\n13,DGN3,3,2.36,PRZ1,F,F,F,T,T,OC11,F,F,F,T,F,68,F\r\n14,DGN2,3.98,3.06,PRZ2,F,F,F,T,T,OC14,F,F,F,T,F,80,T\r\n15,DGN3,1.96,1.4,PRZ1,F,F,F,T,F,OC11,F,F,F,T,F,77,F\r\n16,DGN3,4.68,4.16,PRZ1,F,F,F,T,F,OC12,F,F,F,T,F,62,F\r\n17,DGN2,2.21,1.88,PRZ0,F,T,F,F,F,OC12,F,F,F,T,F,56,F\r\n18,DGN2,2.96,1.67,PRZ0,F,F,F,F,F,OC12,F,F,F,T,F,61,F\r\n19,DGN3,2.6,1.68,PRZ1,F,F,F,T,F,OC12,F,F,F,T,F,70,F\r\n20,DGN3,2.88,2.48,PRZ0,F,F,F,F,F,OC11,F,F,F,T,F,71,F\r\n21,DGN3,4.48,3.48,PRZ0,F,F,F,F,F,OC12,F,F,F,T,F,51,F\r\n22,DGN4,3.32,2.84,PRZ0,F,F,F,F,F,OC12,F,F,F,T,F,62,F\r\n23,DGN3,2.36,1.68,PRZ0,F,F,F,F,F,OC12,F,F,F,T,F,62,F\r\n24,DGN3,3.68,2.32,PRZ0,F,F,F,F,F,OC11,F,F,F,T,F,62,F\r\n25,DGN8,4.32,3.2,PRZ0,F,F,F,F,F,OC11,F,F,F,F,F,58,T\r\n26,DGN5,4.56,72.8,PRZ0,T,T,F,T,F,OC12,F,F,F,T,F,57,F\r\n27,DGN3,3.24,3.08,PRZ1,F,F,F,T,F,OC11,F,F,F,T,F,60,F\r\n28,DGN3,3.4,3.06,PRZ1,F,F,F,T,T,OC11,F,F,F,T,F,68,T\r\n29,DGN3,3.16,2.69,PRZ1,F,F,F,T,T,OC11,F,F,F,T,F,56,F\r\n30,DGN6,3.96,3.28,PRZ0,F,F,F,F,F,OC11,F,F,F,T,F,61,F\r\n31,DGN3,3.24,2.4,PRZ1,T,T,F,F,F,OC14,F,F,F,T,F,55,T\r\n32,DGN3,4.44,3.48,PRZ1,F,F,F,T,F,OC12,F,F,F,F,F,52,F\r\n33,DGN5,2.48,1.95,PRZ1,T,F,F,F,F,OC12,T,F,F,F,F,72,F\r\n34,DGN3,1.81,1.4,PRZ1,F,F,F,T,F,OC12,T,F,F,F,F,68,F\r\n35,DGN2,2.76,2.2,PRZ1,F,F,F,T,F,OC11,F,F,F,F,F,76,F\r\n36,DGN3,2.36,1.6,PRZ0,F,F,F,F,F,OC11,F,F,F,T,F,58,F\r\n37,DGN3,2.2,1.96,PRZ1,F,F,F,T,F,OC12,F,F,F,T,F,71,F\r\n38,DGN3,3.68,2.44,PRZ1,F,T,T,F,F,OC12,T,F,F,F,F,61,F\r\n39,DGN3,4.2,3.08,PRZ0,F,F,F,F,F,OC11,F,F,F,T,F,56,F\r\n40,DGN3,4.6,3.52,PRZ1,F,F,F,T,F,OC11,F,F,F,T,F,52,F\r\n41,DGN5,3.8,2.98,PRZ1,F,F,F,T,F,OC11,F,F,F,T,F,60,T\r\n42,DGN2,3.24,2.52,PRZ1,F,F,F,T,F,OC12,F,F,F,T,F,63,T\r\n43,DGN3,3.2,2.82,PRZ1,F,F,F,T,F,OC12,F,F,F,T,F,68,F\r\n44,DGN5,2.68,2.12,PRZ0,F,F,F,T,F,OC12,F,F,F,T,F,51,T\r\n45,DGN3,3.56,2.68,PRZ1,T,F,F,T,F,OC12,F,F,F,T,F,60,F\r\n46,DGN3,2.48,2.08,PRZ0,F,F,F,F,F,OC11,F,F,F,T,F,60,F\r\n47,DGN3,4.16,3.28,PRZ1,F,F,F,T,F,OC12,F,F,F,T,F,67,F\r\n48,DGN3,2.64,2.12,PRZ1,F,F,F,T,F,OC12,F,F,F,T,F,72,T\r\n49,DGN3,4.44,3.12,PRZ2,F,F,F,T,T,OC12,F,F,F,T,F,59,F\r\n50,DGN3,4.56,3.92,PRZ0,F,F,F,F,F,OC12,F,F,F,F,F,55,F\r\n51,DGN3,2.52,1.96,PRZ1,F,F,F,T,F,OC12,F,F,F,F,F,79,F\r\n52,DGN3,4,2.88,PRZ1,F,F,F,T,F,OC11,F,F,F,T,F,69,F\r\n53,DGN3,3.2,2.52,PRZ2,T,T,T,T,F,OC12,F,F,F,T,F,68,F\r\n54,DGN4,3.76,2.52,PRZ1,F,F,F,T,F,OC12,F,F,F,T,F,75,F\r\n55,DGN3,3.68,3.08,PRZ1,F,F,F,T,F,OC12,F,F,F,T,F,63,F\r\n56,DGN4,3.28,2.36,PRZ1,F,F,F,T,F,OC12,F,F,F,T,F,65,F\r\n57,DGN3,3.72,2.88,PRZ1,F,F,T,T,F,OC11,F,F,F,F,F,37,F\r\n58,DGN3,3.4,2.8,PRZ1,T,F,F,T,T,OC11,T,F,F,T,F,64,T\r\n59,DGN4,5.12,4.28,PRZ0,F,F,F,F,F,OC12,F,F,F,T,F,62,F\r\n60,DGN3,3.84,3.72,PRZ0,F,F,F,F,F,OC12,F,F,F,T,F,58,F\r\n61,DGN3,3.52,2.28,PRZ0,F,F,F,F,F,OC13,F,F,F,T,F,51,T\r\n62,DGN3,3.04,2.04,PRZ2,F,F,F,T,T,OC12,F,F,F,T,F,77,F\r\n63,DGN3,4.96,3.6,PRZ0,F,F,F,F,F,OC11,F,F,F,T,F,56,F\r\n64,DGN3,3.72,2.84,PRZ0,F,F,F,F,F,OC11,T,F,F,F,F,55,F\r\n65,DGN2,3.15,2.76,PRZ1,F,T,F,T,F,OC12,F,F,F,T,F,59,F\r\n66,DGN3,2.88,2.6,PRZ1,F,F,F,T,F,OC12,F,F,F,F,F,54,F\r\n67,DGN3,2.36,2,PRZ0,F,F,F,F,F,OC11,F,F,F,F,F,39,F\r\n68,DGN4,2.32,1.76,PRZ1,F,T,F,T,T,OC11,F,F,F,T,F,62,T\r\n69,DGN3,2.72,2.2,PRZ1,F,F,F,T,F,OC12,F,F,F,T,F,61,F\r\n70,DGN3,3.08,1.8,PRZ1,F,T,F,T,F,OC12,F,F,F,T,F,70 ...

# %%
tds = pd.read_csv(r'ThoraricSurgery.csv')

# %%
tds.head()
# Out:
#    id   DGN  PRE4  PRE5  PRE6 PRE7  ... PRE19 PRE25 PRE30 PRE32 AGE Risk1Yr
# 0   1  DGN2  2.88  2.16  PRZ1    F  ...     F     F     T     F  60       F
# 1   2  DGN3  3.40  1.88  PRZ0    F  ...     F     F     T     F  51       F
# 2   3  DGN3  2.76  2.08  PRZ1    F  ...     F     F     T     F  59       F
# 3   4  DGN3  3.68  3.04  PRZ0    F  ...     F     F     F     F  54       F
# 4   5  DGN3  2.44  0.96  PRZ2    F  ...     F     F     T     F  73       T
#
# [5 rows x 18 columns]

# %% [markdown]
# проверим, есть ли пустые данные и уберем столбец id

# %%
tds = tds.drop('id', axis=1)
tds.isnull().sum()
# Out:
# DGN        0
# PRE4       0
# PRE5       0
# PRE6       0
# PRE7       0
# PRE8       0
# PRE9       0
# PRE10      0
# PRE11      0
# PRE14      0
# PRE17      0
# PRE19      0
# PRE25      0
# PRE30      0
# PRE32      0
# AGE        0
# Risk1Yr    0
# dtype: int64

# %%
tds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 470 entries, 0 to 469
# Data columns (total 17 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   DGN      470 non-null    object
#  1   PRE4     470 non-null    float64
#  2   PRE5     470 non-null    float64
#  3   PRE6     470 non-null    object
#  4   PRE7     470 non-null    object
#  5   PRE8     470 non-null    object
#  6   PRE9     470 non-null    object
#  7   PRE10    470 non-null    object
#  8   PRE11    470 non-null    object
#  9   PRE14    470 non-null    object
#  10  PRE17    470 non-null    object
#  11  PRE19    470 non-null    object
#  12  PRE25    470 non-null    object
#  13  PRE30    470 non-null    object
#  14  PRE32    470 non-null    object
#  15  AGE      470 non-null    int64
#  16  Risk1Yr  470 non-null    object
# dtypes: float64(2), int64(1), object(14)
# memory usage: 62.5+ KB

# %% [markdown]
# уберем лишнее и заменим по максимуму буквы на цифры

# %%
tds[['PRE7', 'PRE8', 'PRE9', 'PRE10', 'PRE11', 'PRE17', 'PRE19', 'PRE25', 'PRE30', 'PRE32', 'Risk1Yr']] = \
(tds[['PRE7', 'PRE8', 'PRE9', 'PRE10', 'PRE11', 'PRE17', 'PRE19', 'PRE25', 'PRE30', 'PRE32', 'Risk1Yr']] == 'T').astype(int)
tds['DGN']   = tds['DGN'].str[-1:].astype(int)
tds['PRE6']  = tds['PRE6'].str[-1:].astype(int)
tds['PRE14'] = tds['PRE14'].str[-1:].astype(int)

# %%
tds.head()
# Out:
#    DGN  PRE4  PRE5  PRE6  PRE7  PRE8  ...  PRE19  PRE25  PRE30  PRE32  AGE  Risk1Yr
# 0    2  2.88  2.16     1     0     0  ...      0      0      1      0   60        0
# 1    3  3.40  1.88     0     0     0  ...      0      0      1      0   51        0
# 2    3  2.76  2.08     1     0     0  ...      0      0      1      0   59        0
# 3    3  3.68  3.04     0     0     0  ...      0      0      0      0   54        0
# 4    3  2.44  0.96     2     0     1  ...      0      0      1      0   73        1
#
# [5 rows x 17 columns]

# %%
columns = ['Диагноз','Ёмкость_легких','Объем_выдоха','Шкала_Зуброда','Боль','Кровохарканье','Одышка',
       'Кашель','Слабость','Размер_опухоли','Диабет','ИМ_6_мес','Заболевание_артерий','Курение','Астма','Возраст','Выживание_год']
tds.columns = columns

# %%
tds.head(3)
# Out:
#    Диагноз  Ёмкость_легких  Объем_выдоха  ...  Астма  Возраст  Выживание_год
# 0        2            2.88          2.16  ...      0       60              0
# 1        3            3.40          1.88  ...      0       51              0
# 2        3            2.76          2.08  ...      0       59              0
#
# [3 rows x 17 columns]

# %% [markdown]
# смотрим нет ли вбросов, ошибок возраста и т.д.

# %%
tds.describe()
# Out:
#           Диагноз  Ёмкость_легких  ...     Возраст  Выживание_год
# count  470.000000      470.000000  ...  470.000000     470.000000
# mean     3.095745        3.281638  ...   62.534043       0.148936
# std      0.722309        0.871395  ...    8.706902       0.356405
# min      1.000000        1.440000  ...   21.000000       0.000000
# 25%      3.000000        2.600000  ...   57.000000       0.000000
# 50%      3.000000        3.160000  ...   62.000000       0.000000
# 75%      3.000000        3.807500  ...   69.000000       0.000000
# max      8.000000        6.300000  ...   87.000000       1.000000
#
# [8 rows x 17 columns]

# %% [markdown]
# Замечаем, что среднее значение диагноза очень уж близко к 3

# %%
tds['Диагноз'].value_counts()
# Out:
# 3    349
# 2     52
# 4     47
# 5     15
# 6      4
# 8      2
# 1      1
# Name: Диагноз, dtype: int64

# %% [markdown]
# проверяем и правда, у нас очень много данных для диагноза 3 и почти нет для диагнозов 1, 8 и 6

# %% [markdown]
# Объединяем 1, 8, 6, 5 диагноз в один

# %%
test = tds.copy()
test['Диагноз'] = np.where(tds['Диагноз'].isin([1, 8, 6, 5]), 1, tds['Диагноз'])

# %%
test['Диагноз'].value_counts()
# Out:
# 3    349
# 2     52
# 4     47
# 1     22
# Name: Диагноз, dtype: int64

# %%
X, y = test.drop('Диагноз', axis=1), test.Диагноз

# %% [markdown]
# вводим рандом форест, чтобы отсеять нерелевантные данные

# %%
parameters = {'n_estimators': range(10, 50, 10), 'max_depth': [1, 3, 5],
             'min_samples_leaf': [1, 2, 3], 'min_samples_split': [2, 4],
             'random_state': [0], 'n_jobs': [-1]}
clf = RandomForestClassifier()

# %%
grid = GridSearchCV(clf, parameters, cv=3)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y)
grid.fit(X_train, y_train)
predictions = grid.predict(X_test)
print(metrics.classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         6
#            2       0.00      0.00      0.00        16
#            3       0.74      0.99      0.85       105
#            4       0.00      0.00      0.00        14
#
#     accuracy                           0.74       141
#    macro avg       0.19      0.25      0.21       141
# weighted avg       0.55      0.74      0.63       141
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
best_grid = grid.best_estimator_
best_grid_features = best_grid.feature_importances_
feature_importances = pd.DataFrame({'features': list(X),
                                   'feature_importances':best_grid_features })
feature_importances.sort_values('feature_importances', ascending=False)
# Out:
#                features  feature_importances
# 1          Объем_выдоха             0.224997
# 14              Возраст             0.210741
# 0        Ёмкость_легких             0.186581
# 8        Размер_опухоли             0.147559
# 15        Выживание_год             0.045097
# 7              Слабость             0.039748
# 4         Кровохарканье             0.034274
# 2         Шкала_Зуброда             0.031180
# 6                Кашель             0.023147
# 12              Курение             0.019042
# 3                  Боль             0.018618
# 5                Одышка             0.011975
# 9                Диабет             0.004390
# 11  Заболевание_артерий             0.001872
# 13                Астма             0.000777
# 10             ИМ_6_мес             0.000000

# %% [markdown]
# Понимаем, что астма и ИМ почти никак не влияют на Диагноз. Удалим лишние данные

# %%
test = test.drop(['Астма', 'ИМ_6_мес'], axis=1)

# %%
 X, y = test.drop('Диагноз', axis=1), test.Диагноз

# %% [markdown]
# логистическая регрессия

# %%
lr = LogisticRegression(class_weight = 'balanced', max_iter=10000)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y)
lr.fit(X_train, y_train)
predictions = lr.predict(X_test)
print(metrics.classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.08      0.25      0.12         4
#            2       0.25      0.45      0.32        11
#            3       0.81      0.41      0.55        70
#            4       0.08      0.22      0.11         9
#
#     accuracy                           0.39        94
#    macro avg       0.30      0.34      0.28        94
# weighted avg       0.64      0.39      0.46        94

# %% [markdown]
# метод опорных векторов

# %%
svm_lin = SVC(kernel='linear', probability=True)
svm_lin.fit(X_train, y_train)
predictions = svm_lin.predict(X_test)
print(metrics.classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         4
#            2       0.00      0.00      0.00        11
#            3       0.74      1.00      0.85        70
#            4       0.00      0.00      0.00         9
#
#     accuracy                           0.74        94
#    macro avg       0.19      0.25      0.21        94
# weighted avg       0.55      0.74      0.64        94
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# метод соседей

# %%
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
predictions = knn.predict(X_test)
print(metrics.classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         4
#            2       0.00      0.00      0.00        11
#            3       0.74      0.99      0.85        70
#            4       0.00      0.00      0.00         9
#
#     accuracy                           0.73        94
#    macro avg       0.19      0.25      0.21        94
# weighted avg       0.55      0.73      0.63        94
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# подгружаем оверсемплер, чтобы создать дополнительные данные

# %%
from imblearn.over_sampling import ADASYN

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y)

augm = ADASYN()
X_train_augm, y_train_augm = augm.fit_resample(np.array(X_train), np.array(y_train))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %%
X_test.head()
# Out:
#      Ёмкость_легких  Объем_выдоха  ...  Возраст  Выживание_год
# 271            3.00          2.16  ...       72              0
# 183            2.80          3.36  ...       56              0
# 247            4.08          3.20  ...       55              0
# 456            2.40          1.24  ...       62              0
# 248            4.56          3.68  ...       62              0
#
# [5 rows x 14 columns]

# %% [markdown]
# логистическая регрессия на дополненных данных

# %% [markdown]
# С использованием RandomizedSearchCV для подбора лучших параметров

# %%
from scipy.stats import uniform
lr1 = LogisticRegression(solver='saga', tol=1e-2, max_iter=10000)



parameters = dict(C=uniform(loc=0, scale=4),
                      penalty=['l2', 'l1'])
clf = RandomizedSearchCV(lr1, parameters, random_state=0, refit=True)
search = clf.fit(X_train_augm, y_train_augm)
search.best_params_
clf.fit(X_train_augm, y_train_augm)
clf = clf.best_estimator_

predictions = clf.predict(X_test)

print(search.best_params_)
print(metrics.classification_report(y_test, predictions))
# Out:
# {'C': 3.2486749151019727, 'penalty': 'l2'}
#               precision    recall  f1-score   support
#
#            1       0.10      0.50      0.17         4
#            2       0.18      0.40      0.25        10
#            3       0.91      0.14      0.25        70
#            4       0.10      0.40      0.16        10
#
#     accuracy                           0.21        94
#    macro avg       0.32      0.36      0.21        94
# weighted avg       0.71      0.21      0.23        94

# %% [markdown]
# Модель на опорных векторах, используя дополненные данные и GridSearchCV для подбора лучшего ядра и параметров

# %%
svm_lin1 = SVC(kernel='linear', probability=True)

parameters = dict(kernel = ['linear', 'poly', 'rbf', 'sigmoid'], degree=[3, 5])
clf1 = GridSearchCV(svm_lin1, parameters, cv=3)
clf1.fit(X_train_augm, y_train_augm)
best_clf1 = clf1.best_estimator_

print(clf1.best_params_)
predictions = best_clf1.predict(X_test)
print(metrics.classification_report(y_test, predictions))
# Out:
# {'degree': 3, 'kernel': 'linear'}
#               precision    recall  f1-score   support
#
#            1       0.08      0.25      0.12         4
#            2       0.25      0.40      0.31        10
#            3       0.77      0.43      0.55        70
#            4       0.11      0.30      0.16        10
#
#     accuracy                           0.40        94
#    macro avg       0.30      0.34      0.29        94
# weighted avg       0.61      0.40      0.47        94

# %% [markdown]
# Метод соседей на дополненных данных
# С применением RandomizedSearchCV для выбора оптимальных параметров

# %%
knn = KNeighborsClassifier()

parameters = dict(n_neighbors = [x for x in range(1,5)], weights = ['uniform', 'distance'], algorithm = ['ball_tree', 'kd_tree'])
clf = RandomizedSearchCV(knn, parameters, random_state=0, refit=True)
clf.fit(X_train_augm, y_train_augm)
best_clf = clf.best_estimator_

predictions = best_clf.predict(X_test)

print(metrics.classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.08      0.25      0.12         4
#            2       0.21      0.30      0.25        10
#            3       0.72      0.56      0.63        70
#            4       0.21      0.30      0.25        10
#
#     accuracy                           0.49        94
#    macro avg       0.31      0.35      0.31        94
# weighted avg       0.59      0.49      0.53        94

# %% [markdown]
# опять рандом форест, но с подчищенными и аугментированными данными

# %%
grid.fit(X_train, y_train)
predictions = grid.predict(X_test)
print(grid.best_params_)
print(metrics.classification_report(y_test, predictions))
# Out:
# {'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10, 'n_jobs': -1, 'random_state': 0}
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         4
#            2       0.00      0.00      0.00        10
#            3       0.74      1.00      0.85        70
#            4       0.00      0.00      0.00        10
#
#     accuracy                           0.74        94
#    macro avg       0.19      0.25      0.21        94
# weighted avg       0.55      0.74      0.64        94
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# В итоге можем заключить, что все модели работают не ояень хорошо, но лучше всего себя показывает метод опорных векторов с линейным ядром, который в некоторых случаях даёт prec = 0.4 и recall = 0.5.
# Немного хуже работает логистическая регрессия.
# Данные предсказаны довольно точно для диагноза номер 3, остальные диагнозы, кроме второго, по
